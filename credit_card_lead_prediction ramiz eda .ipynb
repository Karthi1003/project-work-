# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv(r'C:/Users/91949/Desktop/ICT PROJECT/dataset/train.csv')
test = pd.read_csv(r'C:/Users/91949/Desktop/ICT PROJECT/dataset/test.csv')
sample = pd.read_csv(r'C:/Users/91949/Desktop/ICT PROJECT/dataset/sample_submission.csv')

# %%
train
# Out:
#               ID  Gender  Age Region_Code     Occupation Channel_Code  \
# 0       NNVBBKZB  Female   73       RG268          Other           X3
# 1       IDD62UNG  Female   30       RG277       Salaried           X1
# 2       HD3DSEMC  Female   56       RG268  Self_Employed           X3
# 3       BF3NC7KV    Male   34       RG270       Salaried           X1
# 4       TEASRWXV  Female   30       RG282       Salaried           X1
# ...          ...     ...  ...         ...            ...          ...
# 245720  BPAWWXZN    Male   51       RG284  Self_Employed           X3
# 245721  HFNB7JY8    Male   27       RG268       Salaried           X1
# 245722  GEHAUCWT  Female   26       RG281       Salaried           X1
# 245723  GE7V8SAH  Female   28       RG273       Salaried           X1
# 245724  BOCZSWLJ    Male   29       RG269       Salaried           X1
#
#         Vintage Credit_Product  Avg_Account_Balance Is_Active  Is_Lead
# ...

# %%
test
# Out:
#               ID  Gender  Age Region_Code Occupation Channel_Code  Vintage  \
# 0       VBENBARO    Male   29       RG254      Other           X1       25
# 1       CCMEWNKY    Male   43       RG268      Other           X2       49
# 2       VK3KGA9M    Male   31       RG270   Salaried           X1       14
# 3       TT8RPZVC    Male   29       RG272      Other           X1       33
# 4       SHQZEYTZ  Female   29       RG270      Other           X1       19
# ...          ...     ...  ...         ...        ...          ...      ...
# 105307  DBENJOYI    Male   52       RG268   Salaried           X2       86
# 105308  CWQ72DWS    Male   55       RG277      Other           X2       86
# 105309  HDESC8GU    Male   35       RG254   Salaried           X4       15
# 105310  2PW4SFCA    Male   53       RG254      Other           X3       93
# 105311  F2NOYPPZ    Male   27       RG256   Salaried           X1       21
#
#        Credit_Product  Avg_Account_Balance Is_Active
# ...

# %%
sample
# Out:
#               ID  Is_Lead
# 0       VBENBARO        0
# 1       CCMEWNKY        0
# 2       VK3KGA9M        0
# 3       TT8RPZVC        0
# 4       SHQZEYTZ        0
# ...          ...      ...
# 105307  DBENJOYI        0
# 105308  CWQ72DWS        0
# 105309  HDESC8GU        0
# 105310  2PW4SFCA        0
# 105311  F2NOYPPZ        0
#
# [105312 rows x 2 columns]

# %%
train.tail()
# Out:
#               ID  Gender  Age Region_Code     Occupation Channel_Code  \
# 245720  BPAWWXZN    Male   51       RG284  Self_Employed           X3
# 245721  HFNB7JY8    Male   27       RG268       Salaried           X1
# 245722  GEHAUCWT  Female   26       RG281       Salaried           X1
# 245723  GE7V8SAH  Female   28       RG273       Salaried           X1
# 245724  BOCZSWLJ    Male   29       RG269       Salaried           X1
#
#         Vintage Credit_Product  Avg_Account_Balance Is_Active  Is_Lead
# 245720      109            NaN              1925586        No        0
# 245721       15             No               862952       Yes        0
# 245722       13             No               670659        No        0
# 245723       31             No               407504        No        0
# 245724       21             No              1129276        No        0

# %%
train.shape
# Out:
# (245725, 11)

# %%
test.shape
# Out:
# (105312, 10)

# %%
train.describe()
# Out:
#                  Age        Vintage  Avg_Account_Balance        Is_Lead
# count  245725.000000  245725.000000         2.457250e+05  245725.000000
# mean       43.856307      46.959141         1.128403e+06       0.237208
# std        14.828672      32.353136         8.529364e+05       0.425372
# min        23.000000       7.000000         2.079000e+04       0.000000
# 25%        30.000000      20.000000         6.043100e+05       0.000000
# 50%        43.000000      32.000000         8.946010e+05       0.000000
# 75%        54.000000      73.000000         1.366666e+06       0.000000
# max        85.000000     135.000000         1.035201e+07       1.000000

# %%
test.describe()
# Out:
#                  Age        Vintage  Avg_Account_Balance
# count  105312.000000  105312.000000         1.053120e+05
# mean       43.871002      46.842819         1.134195e+06
# std        14.872890      32.273634         8.662430e+05
# min        24.000000       7.000000         2.259700e+04
# 25%        30.000000      20.000000         6.039822e+05
# 50%        43.000000      32.000000         8.966345e+05
# 75%        54.000000      73.000000         1.371598e+06
# max        85.000000     135.000000         9.908858e+06

# %%
train.isnull().sum()
# Out:
# ID                         0
# Gender                     0
# Age                        0
# Region_Code                0
# Occupation                 0
# Channel_Code               0
# Vintage                    0
# Credit_Product         29325
# Avg_Account_Balance        0
# Is_Active                  0
# Is_Lead                    0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# ID                         0
# Gender                     0
# Age                        0
# Region_Code                0
# Occupation                 0
# Channel_Code               0
# Vintage                    0
# Credit_Product         12522
# Avg_Account_Balance        0
# Is_Active                  0
# dtype: int64

# %%
train.columns
# Out:
# Index(['ID', 'Gender', 'Age', 'Region_Code', 'Occupation', 'Channel_Code',
#        'Vintage', 'Credit_Product', 'Avg_Account_Balance', 'Is_Active',
#        'Is_Lead'],
#       dtype='object')

# %%
print("***** Value counts of target feature *****")
print()
train['Is_Lead'].value_counts()
# Out:
# ***** Value counts of target feature *****
# 0    187437
# 1     58288
# Name: Is_Lead, dtype: int64

# %%
train['Is_Lead'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
columns=[ 'Gender', 'Region_Code', 'Occupation', 'Channel_Code',
        'Credit_Product', 'Is_Active']

for i in columns:
    print("Value counts of",i,"is :")
    print(train[i].value_counts())
    print()
    print("Unique values of",i,"is :",train[i].unique()) 
    print()
# Out:
# Value counts of Gender is :
# Male      134197
# Female    111528
# Name: Gender, dtype: int64
#
# Unique values of Gender is : ['Female' 'Male']
#
# Value counts of Region_Code is :
# RG268    35934
# RG283    29416
# RG254    26840
# RG284    19320
# RG277    12826
# RG280    12775
# RG269     7863
# RG270     7720
# RG261     7633
# RG257     6101
# RG251     5950
# RG282     5829
# RG274     5286
# RG272     5252
# RG281     5093
# RG273     4497
# RG252     4286
# RG279     3976
# RG263     3687
# RG275     3245
# RG260     3110
# RG256     2847
# RG264     2793
# RG276     2764
# RG259     2586
# RG250     2496
# RG255     2018
# RG258     1951
# RG253     1858
# RG278     1822
# RG262     1788
# RG266     1578
# RG265     1546
# RG271     1542
# RG267     1497
# Name: Region_Code, dtype: int64
#
# Unique values of Region_Code is : ['RG268' 'RG277' 'RG270' 'RG282' 'RG261' 'RG265' 'RG283' 'RG254' 'RG269'
#  'RG257' 'RG279' 'RG280' 'RG252' 'RG284' 'RG259' 'RG281' 'RG258' 'RG266'
# ...

# %% [markdown]
# ### Data analysis

# %% [markdown]
# ### UNIVARIENT ANALYSIS

# %%
plt.figure(figsize = (20,6))
plt.xticks(rotation = 90)
sns.countplot(train['Region_Code'])
# Out:
# <AxesSubplot:xlabel='Region_Code', ylabel='count'>

# %%
## Region code univarient
plt.figure(figsize=(12, 6))
sns.countplot(x='Region_Code', data=train, order=train['Region_Code'].value_counts().index)
plt.title('Counts of Region_Code')
plt.xlabel('Region_Code')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize = (20,6))
plt.xticks(rotation = 90)
sns.countplot(train['Vintage'])
# Out:
# <AxesSubplot:xlabel='Vintage', ylabel='count'>

# %%
### Univarient analysis of Vintage
plt.figure(figsize=(20, 6))
sns.countplot(x='Vintage', data=train, order=train['Vintage'].value_counts().index)
plt.title('Counts of Vintage')
plt.xlabel('Vintage')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(train['Vintage'], bins=30, kde = True)
plt.title('Distribution of Vintage')
plt.xlabel('Vintage')
plt.ylabel('Frequency')
plt.show()

# %%
##plt.figure(figsize = (20,6))
#plt.xticks(rotation = 90)
#plt.pie(train['Avg_Account_Balance'])
#plt.xlabel('Average Account Balance')
#plt.show()

# %%
## Univarient analysis of AVERAGE ACCOUNT BALANCE 
## DISCUSS WITH SIR ON LE7
plt.figure(figsize=(10, 6))
sns.histplot(train['Avg_Account_Balance'], bins=40, kde=True)
plt.xlabel('Average Account Balance')
plt.ylabel('Count')
plt.title('Distribution of Average Account Balance')
plt.show()

# %% [markdown]
# ## Bivarient analysis

# %%
train = train.drop(['ID'] , axis = 1)

# %%
#feature_analysis = [features for features in train.columns]
numerical_features = [features for features in train.columns if train[features].dtypes != 'O']

# %%
numerical_features
# Out:
# ['Age', 'Vintage', 'Avg_Account_Balance', 'Is_Lead']

# %%
categorical_features = [features for features in train.columns if train[features].dtypes == 'O']

# %%
categorical_features
# Out:
# ['Gender',
#  'Region_Code',
#  'Occupation',
#  'Channel_Code',
#  'Credit_Product',
#  'Is_Active']

# %%
#for feature in categorical_features:
    #if feature != 'Region_Code':
        #data = train.copy()
        #data.groupby(feature)['Vintage'].median().plot.bar()
        #plt.xticks(rotation = 90)
        #plt.xlabel(feature)
        #plt.ylabel('Vintage')
        #plt.title('Distribution between '+feature+ 'v/s vintage' )
        #plt.show()

# %% [markdown]
# ### Gender v/s vintage

# %%
#plt.figure(figsize=(8, 6)
sns.barplot(x='Gender', y='Vintage', data=train, ci = None)
plt.title('Vintage vs. Gender')
plt.show()

# %% [markdown]
# ### Occupation v/s Vintage

# %%
#plt.figure(figsize=(8, 6))
sns.barplot(x='Occupation', y='Vintage', data=train, ci = None)
plt.title('Vintage vs. Occupation')
plt.show()

# %% [markdown]
# ### vintage v/s channel code

# %%
#plt.figure(figsize=(8, 6))
sns.barplot(x='Channel_Code', y='Vintage', data=train, ci = None)
plt.title('Vintage vs. Channel_Code')
plt.show()

# %% [markdown]
# ### Vintage v/s Credit product

# %%
#plt.figure(figsize=(8, 6))
sns.barplot(x='Credit_Product', y='Vintage', data=train, ci = None)
plt.title('Vintage vs. Credit_Product (Bar Plot)')
plt.show()

# %%
# Credit Product Vs Vintage

contingency_table = pd.crosstab(train['Vintage'], train['Credit_Product'])

# Plot the contingency table
contingency_table.plot(kind='bar', figsize=(20, 10))
plt.xlabel('Vintage')
plt.ylabel('Count')
plt.legend(title='Vintage Vs Credit Product')
plt.show()

# %% [markdown]
# ### Vintage v/s Is Active

# %%
#plt.figure(figsize=(8, 6))
sns.barplot(x='Is_Active', y='Vintage', data=train, ci = None)
plt.title('Vintage vs. Is_Active (Bar Plot)')
plt.show()

# %% [markdown]
# ### Vintage v/s Region Code

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Region_Code', y='Vintage', data=train, order=train['Region_Code'].value_counts().index,  ci = None)
plt.xticks(rotation = 90)
plt.title('Vintage vs. Region Code')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Region_Code', y='Vintage', data=train)
plt.title('Vintage vs. Region_Code')
plt.xlabel('Region_Code')
plt.ylabel('Vintage')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Vintage v/s Is Lead

# %%
#plt.figure(figsize=(8, 6))
sns.barplot(x='Is_Lead', y='Vintage', data=train, ci = None)
plt.title('Vintage vs. Is_Lead (Bar Plot)')
plt.show()

# %%
contingency_table = pd.crosstab(train['Vintage'], train['Is_Lead'])     
print(contingency_table)
contingency_table.plot(kind='bar',figsize=(20,10))
                
plt.xlabel('Vintage')
plt.ylabel('Count')
plt.title(' Vintage vs Is_Lead')

plt.legend(title='Is_Lead')

plt.show()
# Out:
# Is_Lead      0     1
# Vintage
# 7          501   147
# 8          484   135
# 9          490   148
# 13       10499  1839
# 14       10463  1804
# ...        ...   ...
# 128        313   188
# 129        336   163
# 133         15     3
# 134          8     6
# 135         15     4
#
# [66 rows x 2 columns]

# %% [markdown]
# ### Vintage V/s Age

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='Vintage', data=train, alpha = 0.5)
plt.title('Vintage vs. Age')
plt.xlabel('Age')
plt.ylabel('Vintage')
plt.show()

# %% [markdown]
# ### Vintage v/s Average Account Balance

# %%
### DISCUSS WITH SIR
plt.figure(figsize=(10, 6)) 
sns.scatterplot(x='Avg_Account_Balance', y='Vintage', data=train)
plt.title('Avg_Account_Balance v/s Vintage')
plt.show()

# %% [markdown]
# ### BIVARIENT ANALYSIS ON AVERAGE ACCOUNT BALANCE

# %% [markdown]
# ## Average account balance v/s Credit Product

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Credit_Product', y='Avg_Account_Balance', data=train)
plt.title('Avg_Account_Balance vs. Credit_Product')
plt.show()

# %%
sns.barplot(x='Credit_Product', y='Avg_Account_Balance', data=train, ci = None)
plt.title('Average Account Balance v/s Credit_Product')
plt.show()

# %% [markdown]
# ### Avg Account Balance v/s Is Lead

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Is_Lead', y='Avg_Account_Balance', data=train)
plt.title('Avg_Account_Balance vs. Is_Lead')
plt.show()

# %% [markdown]
# ### Average Account Balance v/s Is Active

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Is_Active', y='Avg_Account_Balance', data=train)
plt.title('Avg_Account_Balance vs. Is_Active')
plt.show()

# %%
sns.barplot(x='Is_Active', y='Avg_Account_Balance', data=train, ci = None)
plt.title('Average Account Balance v/s Is_Active')
plt.show()

# %% [markdown]
# ### Average Account Balance v/s Age

# %%
# Age Vs Average account balance
age_groups = ['0-4', '5-9', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39', '40-44', '45-49', '50-54', '55-59', '60-64', '65-69', '70-74', '75+']
age_intervals = list(range(0, 81, 5))
train['Age_Group'] = pd.cut(train['Age'], bins=age_intervals, labels=age_groups)
average_account_balance_by_age = train.groupby('Age_Group')['Avg_Account_Balance'].mean()

# Plot the bar chart
plt.figure(figsize=(12, 6))
plt.bar(average_account_balance_by_age.index, average_account_balance_by_age)
plt.xlabel('Age Intervals')
plt.ylabel('Average Account Balance')
plt.title('Average Account Balance by Age Intervals')
plt.show()

# %% [markdown]
# ###  avg acc bal v/s channel code

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Channel_Code', y='Avg_Account_Balance', data=train)
plt.title('Avg_Account_Balance v/s Channel_Code ')
plt.xlabel('Channel_Code')
plt.ylabel('Avg_Account_Balance')
plt.show()

# %% [markdown]
# ### average account balance v/s Gender

# %%
sns.barplot(x='Gender', y='Avg_Account_Balance', data=train,ci=None)
plt.xlabel('Gender')
plt.ylabel('Avg_Account_Balance')
plt.title('Relationship between Avg_Account_Balance and Gender')
# Out:
# Text(0.5, 1.0, 'Relationship between Gender and Avg_Account_Balance')

# %% [markdown]
# ### average account balance v/Occupation

# %%
sns.boxplot(x='Occupation', y='Avg_Account_Balance', data=train)

# Set the title and labels for the plot
plt.title('Bivariate Analysis of Occupation and Avg_Account_Balance')
plt.xlabel('Occupation')
plt.ylabel('Avg_Account_Balance')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=90)

# Display the plot
plt.show()
